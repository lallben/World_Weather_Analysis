# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Assign the latitudes and longitudes to a list called coordinates
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | almeirim
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | carman
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | port lincoln
# Processing Record 8 of Set 1 | te anau
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | langfang
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | chodavaram
# Processing Record 14 of Set 1 | kavaratti
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | jiaojiang
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 1 | porto novo
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | fortuna
# Processing Record 29 of Set 1 | xichang
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | tocopilla
# Processing Record 33 of Set 1 | coxim
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | luwuk
# Processing Record 36 of Set 1 | grindavik
# Processing Record 37 of Set 1 | naryan-mar
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | oranjestad
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | lucapa
# Processing Record 45 of Set 1 | la palma
# Processing Record 46 of Set 1 | conceicao do araguaia
# Processing Record 47 of Set 1 | saint george
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | belebey
# Processing Record 50 of Set 1 | macusani
# Processing Record 1 of Set 2 | hasaki
# Processing Record 2 of Set 2 | zawadzkie
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | seymchan
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | nizhniy baskunchak
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | mindelo
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | joacaba
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | okato
# Processing Record 15 of Set 2 | santa isabel
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | lumby
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | roald
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | port macquarie
# Processing Record 25 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 2 | doha
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | pochutla
# Processing Record 29 of Set 2 | quang ngai
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | salinas
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | paamiut
# Processing Record 34 of Set 2 | coihaique
# Processing Record 35 of Set 2 | loandjili
# Processing Record 36 of Set 2 | alice springs
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | udachnyy
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | mayo
# Processing Record 41 of Set 2 | necochea
# Processing Record 42 of Set 2 | salinopolis
# Processing Record 43 of Set 2 | chumikan
# Processing Record 44 of Set 2 | nanortalik
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | bengkulu
# Processing Record 47 of Set 2 | otradnoye
# Processing Record 48 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 2 | buin
# Processing Record 50 of Set 2 | bauchi
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | viedma
# Processing Record 4 of Set 3 | bullhead city
# Processing Record 5 of Set 3 | busselton
# Processing Record 6 of Set 3 | pingliang
# Processing Record 7 of Set 3 | inirida
# Processing Record 8 of Set 3 | klaksvik
# Processing Record 9 of Set 3 | peniche
# Processing Record 10 of Set 3 | saint-georges
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | oyem
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | raudeberg
# Processing Record 15 of Set 3 | lorengau
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 3 | nyurba
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | dingle
# Processing Record 21 of Set 3 | rocha
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | hermanus
# Processing Record 24 of Set 3 | coalcoman
# City not found. Skipping...
# Processing Record 25 of Set 3 | vestmanna
# Processing Record 26 of Set 3 | jerantut
# Processing Record 27 of Set 3 | koregaon
# Processing Record 28 of Set 3 | karasburg
# Processing Record 29 of Set 3 | morondava
# Processing Record 30 of Set 3 | yumen
# Processing Record 31 of Set 3 | coffeyville
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | fayaoue
# Processing Record 36 of Set 3 | lima
# Processing Record 37 of Set 3 | richards bay
# Processing Record 38 of Set 3 | zyryanovskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | turukhansk
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 3 | totma
# Processing Record 43 of Set 3 | presidencia roque saenz pena
# Processing Record 44 of Set 3 | seoul
# Processing Record 45 of Set 3 | avera
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | bajil
# Processing Record 48 of Set 3 | husavik
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | geraldton
# Processing Record 1 of Set 4 | marawi
# Processing Record 2 of Set 4 | hobyo
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | labuhan
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | camabatela
# Processing Record 8 of Set 4 | tarakan
# Processing Record 9 of Set 4 | graham
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | buchanan
# Processing Record 13 of Set 4 | jablah
# Processing Record 14 of Set 4 | komsomolskiy
# Processing Record 15 of Set 4 | veshkayma
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | san patricio
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | otjiwarongo
# Processing Record 21 of Set 4 | eydhafushi
# Processing Record 22 of Set 4 | ancud
# Processing Record 23 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 24 of Set 4 | manokwari
# Processing Record 25 of Set 4 | rawson
# Processing Record 26 of Set 4 | pittsfield
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | sembe
# Processing Record 29 of Set 4 | lata
# Processing Record 30 of Set 4 | wewak
# Processing Record 31 of Set 4 | eyl
# Processing Record 32 of Set 4 | san cristobal
# Processing Record 33 of Set 4 | eghezee
# Processing Record 34 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | iskateley
# Processing Record 37 of Set 4 | kimbe
# Processing Record 38 of Set 4 | holland
# Processing Record 39 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 4 | lakefield
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | kalakamati
# Processing Record 43 of Set 4 | kirakira
# Processing Record 44 of Set 4 | half moon bay
# Processing Record 45 of Set 4 | sola
# Processing Record 46 of Set 4 | silver city
# Processing Record 47 of Set 4 | east chicago
# Processing Record 48 of Set 4 | san luis
# Processing Record 49 of Set 4 | lagoa
# Processing Record 50 of Set 4 | east london
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | padang
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | puerto ayora
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | lahijan
# Processing Record 7 of Set 5 | tautira
# Processing Record 8 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 5 | bolgatanga
# Processing Record 10 of Set 5 | buala
# Processing Record 11 of Set 5 | belmonte
# Processing Record 12 of Set 5 | ye
# City not found. Skipping...
# Processing Record 13 of Set 5 | bathsheba
# Processing Record 14 of Set 5 | suchil
# Processing Record 15 of Set 5 | la ronge
# Processing Record 16 of Set 5 | hilo
# Processing Record 17 of Set 5 | amazar
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | tieling
# Processing Record 20 of Set 5 | marzuq
# Processing Record 21 of Set 5 | taoudenni
# Processing Record 22 of Set 5 | sompeta
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | margate
# Processing Record 25 of Set 5 | nome
# Processing Record 26 of Set 5 | ayan
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | cidreira
# Processing Record 29 of Set 5 | kropotkin
# Processing Record 30 of Set 5 | saint-joseph
# Processing Record 31 of Set 5 | serafimovich
# Processing Record 32 of Set 5 | kodiak
# Processing Record 33 of Set 5 | karlstad
# Processing Record 34 of Set 5 | luba
# Processing Record 35 of Set 5 | curvelo
# Processing Record 36 of Set 5 | kamenka
# Processing Record 37 of Set 5 | riyadh
# Processing Record 38 of Set 5 | jining
# Processing Record 39 of Set 5 | lavrentiya
# Processing Record 40 of Set 5 | cayenne
# Processing Record 41 of Set 5 | mandeville
# Processing Record 42 of Set 5 | antsohihy
# Processing Record 43 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 5 | guerrero negro
# Processing Record 46 of Set 5 | kysyl-syr
# Processing Record 47 of Set 5 | kruisfontein
# Processing Record 48 of Set 5 | port-gentil
# Processing Record 49 of Set 5 | launceston
# Processing Record 50 of Set 5 | lasa
# Processing Record 1 of Set 6 | thyboron
# Processing Record 2 of Set 6 | touros
# Processing Record 3 of Set 6 | clyde river
# Processing Record 4 of Set 6 | aklavik
# Processing Record 5 of Set 6 | sao jose da coroa grande
# Processing Record 6 of Set 6 | suntar
# Processing Record 7 of Set 6 | broken hill
# Processing Record 8 of Set 6 | portland
# Processing Record 9 of Set 6 | castro
# Processing Record 10 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 6 | tazovskiy
# Processing Record 12 of Set 6 | huarmey
# Processing Record 13 of Set 6 | sinnamary
# Processing Record 14 of Set 6 | harbour breton
# Processing Record 15 of Set 6 | salalah
# Processing Record 16 of Set 6 | norman wells
# Processing Record 17 of Set 6 | dekar
# Processing Record 18 of Set 6 | moron
# Processing Record 19 of Set 6 | talnakh
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | mayya
# Processing Record 22 of Set 6 | upernavik
# Processing Record 23 of Set 6 | la paz
# Processing Record 24 of Set 6 | saint-paul
# Processing Record 25 of Set 6 | caravelas
# Processing Record 26 of Set 6 | morelia
# Processing Record 27 of Set 6 | taltal
# Processing Record 28 of Set 6 | chiman
# Processing Record 29 of Set 6 | ambilobe
# Processing Record 30 of Set 6 | kapit
# Processing Record 31 of Set 6 | mackay
# Processing Record 32 of Set 6 | adrar
# Processing Record 33 of Set 6 | mbini
# Processing Record 34 of Set 6 | isangel
# Processing Record 35 of Set 6 | gamba
# Processing Record 36 of Set 6 | colares
# Processing Record 37 of Set 6 | nachingwea
# Processing Record 38 of Set 6 | gazojak
# Processing Record 39 of Set 6 | alamosa
# Processing Record 40 of Set 6 | chippewa falls
# Processing Record 41 of Set 6 | marfino
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | asgabat
# Processing Record 44 of Set 6 | garowe
# Processing Record 45 of Set 6 | hovd
# Processing Record 46 of Set 6 | civitavecchia
# Processing Record 47 of Set 6 | valle de banderas
# Processing Record 48 of Set 6 | horta
# Processing Record 49 of Set 6 | formosa
# Processing Record 50 of Set 6 | baryatino
# Processing Record 1 of Set 7 | balkhash
# Processing Record 2 of Set 7 | pangai
# Processing Record 3 of Set 7 | mocuba
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | ixtapa
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | thaton
# Processing Record 9 of Set 7 | praia da vitoria
# Processing Record 10 of Set 7 | florian
# Processing Record 11 of Set 7 | zhangye
# Processing Record 12 of Set 7 | tual
# Processing Record 13 of Set 7 | chinampa
# Processing Record 14 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | wajir
# Processing Record 16 of Set 7 | fort madison
# Processing Record 17 of Set 7 | atbasar
# Processing Record 18 of Set 7 | valparai
# Processing Record 19 of Set 7 | lusambo
# Processing Record 20 of Set 7 | maragogi
# Processing Record 21 of Set 7 | zhanakorgan
# Processing Record 22 of Set 7 | quixada
# Processing Record 23 of Set 7 | talcahuano
# Processing Record 24 of Set 7 | porto velho
# Processing Record 25 of Set 7 | tadine
# Processing Record 26 of Set 7 | karratha
# Processing Record 27 of Set 7 | plettenberg bay
# Processing Record 28 of Set 7 | cabedelo
# Processing Record 29 of Set 7 | grand gaube
# Processing Record 30 of Set 7 | christchurch
# Processing Record 31 of Set 7 | chalus
# Processing Record 32 of Set 7 | namatanai
# Processing Record 33 of Set 7 | acapulco
# Processing Record 34 of Set 7 | mabay
# Processing Record 35 of Set 7 | podor
# Processing Record 36 of Set 7 | diffa
# Processing Record 37 of Set 7 | aranos
# Processing Record 38 of Set 7 | zhigansk
# Processing Record 39 of Set 7 | ponta delgada
# Processing Record 40 of Set 7 | bowen
# Processing Record 41 of Set 7 | pitimbu
# Processing Record 42 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 7 | kotelnikovo
# Processing Record 44 of Set 7 | olafsvik
# Processing Record 45 of Set 7 | tartagal
# Processing Record 46 of Set 7 | marathopolis
# City not found. Skipping...
# Processing Record 47 of Set 7 | tawnat
# City not found. Skipping...
# Processing Record 48 of Set 7 | flin flon
# Processing Record 49 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 7 | tessalit
# Processing Record 1 of Set 8 | brae
# Processing Record 2 of Set 8 | leningradskiy
# Processing Record 3 of Set 8 | hofn
# Processing Record 4 of Set 8 | kondagaon
# Processing Record 5 of Set 8 | jackson
# Processing Record 6 of Set 8 | iqaluit
# Processing Record 7 of Set 8 | manado
# Processing Record 8 of Set 8 | road town
# Processing Record 9 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 8 | deputatskiy
# Processing Record 11 of Set 8 | maltahohe
# Processing Record 12 of Set 8 | katsuura
# Processing Record 13 of Set 8 | umm lajj
# Processing Record 14 of Set 8 | mangalia
# Processing Record 15 of Set 8 | jazzin
# City not found. Skipping...
# Processing Record 16 of Set 8 | plastun
# Processing Record 17 of Set 8 | tambopata
# Processing Record 18 of Set 8 | saldanha
# Processing Record 19 of Set 8 | motygino
# Processing Record 20 of Set 8 | ewa beach
# Processing Record 21 of Set 8 | nantucket
# Processing Record 22 of Set 8 | kincardine
# Processing Record 23 of Set 8 | shibukawa
# Processing Record 24 of Set 8 | buraydah
# Processing Record 25 of Set 8 | bartica
# Processing Record 26 of Set 8 | cap malheureux
# Processing Record 27 of Set 8 | kuressaare
# Processing Record 28 of Set 8 | khor
# Processing Record 29 of Set 8 | ligayan
# Processing Record 30 of Set 8 | torbay
# Processing Record 31 of Set 8 | baruun-urt
# Processing Record 32 of Set 8 | kologriv
# Processing Record 33 of Set 8 | oktyabrskiy
# Processing Record 34 of Set 8 | turbat
# Processing Record 35 of Set 8 | nemuro
# Processing Record 36 of Set 8 | lufilufi
# Processing Record 37 of Set 8 | hamilton
# Processing Record 38 of Set 8 | vanavara
# Processing Record 39 of Set 8 | meadow lake
# Processing Record 40 of Set 8 | pauini
# Processing Record 41 of Set 8 | hambantota
# Processing Record 42 of Set 8 | volcan
# Processing Record 43 of Set 8 | paragominas
# Processing Record 44 of Set 8 | qaqortoq
# Processing Record 45 of Set 8 | quelimane
# Processing Record 46 of Set 8 | camopi
# Processing Record 47 of Set 8 | siderno
# Processing Record 48 of Set 8 | jibuti
# Processing Record 49 of Set 8 | liku
# Processing Record 50 of Set 8 | knysna
# Processing Record 1 of Set 9 | caudry
# Processing Record 2 of Set 9 | almansa
# Processing Record 3 of Set 9 | fort nelson
# Processing Record 4 of Set 9 | kununurra
# Processing Record 5 of Set 9 | havre-saint-pierre
# Processing Record 6 of Set 9 | payo
# Processing Record 7 of Set 9 | toppenish
# Processing Record 8 of Set 9 | kangar
# Processing Record 9 of Set 9 | albertville
# Processing Record 10 of Set 9 | hudson bay
# Processing Record 11 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 9 | petauke
# Processing Record 13 of Set 9 | bonavista
# Processing Record 14 of Set 9 | ternate
# Processing Record 15 of Set 9 | yulara
# Processing Record 16 of Set 9 | rodrigues alves
# Processing Record 17 of Set 9 | port blair
# Processing Record 18 of Set 9 | gao
# Processing Record 19 of Set 9 | khuzhir
# Processing Record 20 of Set 9 | beyneu
# Processing Record 21 of Set 9 | savinka
# Processing Record 22 of Set 9 | kristiansund
# Processing Record 23 of Set 9 | savonlinna
# Processing Record 24 of Set 9 | whitehorse
# Processing Record 25 of Set 9 | manaure
# Processing Record 26 of Set 9 | luanda
# Processing Record 27 of Set 9 | bat khela
# Processing Record 28 of Set 9 | saravan
# Processing Record 29 of Set 9 | ossora
# Processing Record 30 of Set 9 | camana
# Processing Record 31 of Set 9 | jitra
# Processing Record 32 of Set 9 | thinadhoo
# Processing Record 33 of Set 9 | delano
# Processing Record 34 of Set 9 | lompoc
# Processing Record 35 of Set 9 | gimli
# Processing Record 36 of Set 9 | nuuk
# Processing Record 37 of Set 9 | muskogee
# Processing Record 38 of Set 9 | keti bandar
# Processing Record 39 of Set 9 | bridlington
# Processing Record 40 of Set 9 | vao
# Processing Record 41 of Set 9 | sogdiondon
# City not found. Skipping...
# Processing Record 42 of Set 9 | maicao
# Processing Record 43 of Set 9 | valparaiso
# Processing Record 44 of Set 9 | moerai
# Processing Record 45 of Set 9 | kyabe
# Processing Record 46 of Set 9 | manama
# Processing Record 47 of Set 9 | havelock
# Processing Record 48 of Set 9 | lensk
# Processing Record 49 of Set 9 | yueyang
# Processing Record 50 of Set 9 | kviteseid
# Processing Record 1 of Set 10 | barcelos
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | nizwa
# Processing Record 4 of Set 10 | sioux lookout
# Processing Record 5 of Set 10 | lotofaga
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | parkes
# Processing Record 8 of Set 10 | port arthur
# Processing Record 9 of Set 10 | leh
# Processing Record 10 of Set 10 | zyryanka
# Processing Record 11 of Set 10 | fort morgan
# Processing Record 12 of Set 10 | russkiy aktash
# Processing Record 13 of Set 10 | zhireken
# Processing Record 14 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 10 | burica
# City not found. Skipping...
# Processing Record 16 of Set 10 | batemans bay
# Processing Record 17 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 10 | guatire
# Processing Record 19 of Set 10 | otjimbingwe
# Processing Record 20 of Set 10 | chunhuhub
# Processing Record 21 of Set 10 | camacha
# Processing Record 22 of Set 10 | filadelfia
# Processing Record 23 of Set 10 | dormidontovka
# Processing Record 24 of Set 10 | koslan
# Processing Record 25 of Set 10 | veselynove
# Processing Record 26 of Set 10 | mount pleasant
# Processing Record 27 of Set 10 | sonoita
# Processing Record 28 of Set 10 | asha
# Processing Record 29 of Set 10 | rio das ostras
# Processing Record 30 of Set 10 | dumas
# Processing Record 31 of Set 10 | chara
# Processing Record 32 of Set 10 | grass valley
# Processing Record 33 of Set 10 | yar-sale
# Processing Record 34 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 35 of Set 10 | taguatinga
# Processing Record 36 of Set 10 | pemangkat
# Processing Record 37 of Set 10 | byron bay
# Processing Record 38 of Set 10 | moyale
# Processing Record 39 of Set 10 | lazurne
# Processing Record 40 of Set 10 | imola
# Processing Record 41 of Set 10 | ust-omchug
# Processing Record 42 of Set 10 | porto walter
# Processing Record 43 of Set 10 | arica
# Processing Record 44 of Set 10 | besuki
# Processing Record 45 of Set 10 | axim
# Processing Record 46 of Set 10 | guilin
# Processing Record 47 of Set 10 | varca
# Processing Record 48 of Set 10 | olavarria
# Processing Record 49 of Set 10 | college
# Processing Record 50 of Set 10 | ayagoz
# Processing Record 1 of Set 11 | walvis bay
# Processing Record 2 of Set 11 | halifax
# Processing Record 3 of Set 11 | synya
# Processing Record 4 of Set 11 | lodja
# Processing Record 5 of Set 11 | uyuni
# Processing Record 6 of Set 11 | kembe
# Processing Record 7 of Set 11 | port shepstone
# Processing Record 8 of Set 11 | le port
# Processing Record 9 of Set 11 | jacqueville
# Processing Record 10 of Set 11 | iwanai
# Processing Record 11 of Set 11 | dumai
# Processing Record 12 of Set 11 | conneaut
# Processing Record 13 of Set 11 | hersbruck
# Processing Record 14 of Set 11 | rundu
# Processing Record 15 of Set 11 | tigre
# Processing Record 16 of Set 11 | skelleftea
# Processing Record 17 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 18 of Set 11 | kidal
# Processing Record 19 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 20 of Set 11 | marshall
# Processing Record 21 of Set 11 | martapura
# Processing Record 22 of Set 11 | diu
# Processing Record 23 of Set 11 | ucluelet
# Processing Record 24 of Set 11 | narsaq
# Processing Record 25 of Set 11 | tricase
# Processing Record 26 of Set 11 | coos bay
# Processing Record 27 of Set 11 | kvarkeno
# Processing Record 28 of Set 11 | kamina
# Processing Record 29 of Set 11 | juruti
# Processing Record 30 of Set 11 | donegal
# Processing Record 31 of Set 11 | petatlan
# Processing Record 32 of Set 11 | hami
# Processing Record 33 of Set 11 | vestmannaeyjar
# Processing Record 34 of Set 11 | kongoussi
# Processing Record 35 of Set 11 | winsum
# Processing Record 36 of Set 11 | abha
# Processing Record 37 of Set 11 | henties bay
# Processing Record 38 of Set 11 | poum
# Processing Record 39 of Set 11 | yendi
# Processing Record 40 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 11 | ofaqim
# Processing Record 42 of Set 11 | murgab
# Processing Record 43 of Set 11 | puksoozero
# Processing Record 44 of Set 11 | kisanga
# Processing Record 45 of Set 11 | alekseyevka
# Processing Record 46 of Set 11 | hokitika
# Processing Record 47 of Set 11 | murray bridge
# Processing Record 48 of Set 11 | bichura
# Processing Record 49 of Set 11 | ust-tsilma
# Processing Record 50 of Set 11 | robinson
# Processing Record 1 of Set 12 | ust-ilimsk
# Processing Record 2 of Set 12 | tuatapere
# Processing Record 3 of Set 12 | mokhsogollokh
# Processing Record 4 of Set 12 | aksu
# Processing Record 5 of Set 12 | ahipara
# Processing Record 6 of Set 12 | la baule-escoublac
# Processing Record 7 of Set 12 | chicama
# Processing Record 8 of Set 12 | gainesville
# Processing Record 9 of Set 12 | gouyave
# Processing Record 10 of Set 12 | dawlatabad
# Processing Record 11 of Set 12 | sawai madhopur
# Processing Record 12 of Set 12 | okha
# Processing Record 13 of Set 12 | harper
# Processing Record 14 of Set 12 | orange cove
# Processing Record 15 of Set 12 | telimele
# Processing Record 16 of Set 12 | guiratinga
# Processing Record 17 of Set 12 | azovo
# Processing Record 18 of Set 12 | marrakesh
# Processing Record 19 of Set 12 | muros
# Processing Record 20 of Set 12 | nedjo
# Processing Record 21 of Set 12 | dingzhou
# Processing Record 22 of Set 12 | susanville
# Processing Record 23 of Set 12 | nizhniy kuranakh
# Processing Record 24 of Set 12 | broome
# Processing Record 25 of Set 12 | portree
# Processing Record 26 of Set 12 | kendari
# Processing Record 27 of Set 12 | kalangala
# Processing Record 28 of Set 12 | springbok
# Processing Record 29 of Set 12 | boa vista
# Processing Record 30 of Set 12 | qianan
# Processing Record 31 of Set 12 | vanimo
# Processing Record 32 of Set 12 | auki
# Processing Record 33 of Set 12 | kamakwie
# Processing Record 34 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 12 | hit
# Processing Record 36 of Set 12 | barcelona
# Processing Record 37 of Set 12 | san lazaro
# Processing Record 38 of Set 12 | mingshui
# Processing Record 39 of Set 12 | danville
# Processing Record 40 of Set 12 | santarem
# Processing Record 41 of Set 12 | navabad
# City not found. Skipping...
# Processing Record 42 of Set 12 | ugoofaaru
# Processing Record 43 of Set 12 | tabriz
# Processing Record 44 of Set 12 | russell
# Processing Record 45 of Set 12 | olonets
# Processing Record 46 of Set 12 | belmonte mezzagno
# Processing Record 47 of Set 12 | powell river
# Processing Record 48 of Set 12 | luganville
# Processing Record 49 of Set 12 | bafq
# Processing Record 50 of Set 12 | namibe
# Processing Record 1 of Set 13 | asfi
# Processing Record 2 of Set 13 | puerto escondido
# Processing Record 3 of Set 13 | borgustanskaya
# Processing Record 4 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 5 of Set 13 | artesia
# Processing Record 6 of Set 13 | timra
# Processing Record 7 of Set 13 | gat
# Processing Record 8 of Set 13 | praia
# Processing Record 9 of Set 13 | ferme-neuve
# Processing Record 10 of Set 13 | kapuvar
# Processing Record 11 of Set 13 | bandarbeyla
# Processing Record 12 of Set 13 | krasnoselkup
# Processing Record 13 of Set 13 | abu kamal
# Processing Record 14 of Set 13 | huaibei
# Processing Record 15 of Set 13 | ust-kuyga
# Processing Record 16 of Set 13 | aksarka
# Processing Record 17 of Set 13 | natal
# Processing Record 18 of Set 13 | klyuchi
# Processing Record 19 of Set 13 | saint-augustin
# Processing Record 20 of Set 13 | asau
# Processing Record 21 of Set 13 | jaguariaiva
# Processing Record 22 of Set 13 | beringovskiy
# Processing Record 23 of Set 13 | bizhbulyak
# Processing Record 24 of Set 13 | ust-maya
# Processing Record 25 of Set 13 | egvekinot
# Processing Record 26 of Set 13 | khorinsk
# Processing Record 27 of Set 13 | kapoeta
# Processing Record 28 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 13 | copacabana
# Processing Record 30 of Set 13 | basco
# Processing Record 31 of Set 13 | parainen
# Processing Record 32 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 13 | vila franca do campo
# Processing Record 34 of Set 13 | matagami
# Processing Record 35 of Set 13 | myitkyina
# Processing Record 36 of Set 13 | alghero
# Processing Record 37 of Set 13 | east stroudsburg
# Processing Record 38 of Set 13 | kizlyar
# Processing Record 39 of Set 13 | kobojango
# City not found. Skipping...
# Processing Record 40 of Set 13 | pierre
# Processing Record 41 of Set 13 | svirstroy
# Processing Record 42 of Set 13 | benguela
# Processing Record 43 of Set 13 | soltsy
# Processing Record 44 of Set 13 | luderitz
# Processing Record 45 of Set 13 | leogane
# Processing Record 46 of Set 13 | uruacu
# Processing Record 47 of Set 13 | puerto madero
# Processing Record 48 of Set 13 | pismo beach
# Processing Record 49 of Set 13 | zorgo
# Processing Record 50 of Set 13 | po
# City not found. Skipping...
# Processing Record 1 of Set 14 | biak
# Processing Record 2 of Set 14 | moka
# Processing Record 3 of Set 14 | tukan
# Processing Record 4 of Set 14 | port hedland
# Processing Record 5 of Set 14 | stokmarknes
# Processing Record 6 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 14 | obihiro
# Processing Record 8 of Set 14 | san roque
# Processing Record 9 of Set 14 | abnub
# Processing Record 10 of Set 14 | porto santo
# Processing Record 11 of Set 14 | bonnyville
# Processing Record 12 of Set 14 | carutapera
# Processing Record 13 of Set 14 | moose factory
# Processing Record 14 of Set 14 | santiago del estero
# Processing Record 15 of Set 14 | hualmay
# Processing Record 16 of Set 14 | lebedinyy
# Processing Record 17 of Set 14 | vilcun
# Processing Record 18 of Set 14 | tapejara
# Processing Record 19 of Set 14 | sambava
# Processing Record 20 of Set 14 | mulege
# Processing Record 21 of Set 14 | beloha
# Processing Record 22 of Set 14 | carmo do paranaiba
# Processing Record 23 of Set 14 | sobolevo
# Processing Record 24 of Set 14 | vostok
# Processing Record 25 of Set 14 | uthal
# Processing Record 26 of Set 14 | dasoguz
# Processing Record 27 of Set 14 | abu dhabi
# Processing Record 28 of Set 14 | ranong
# Processing Record 29 of Set 14 | mountain home
# Processing Record 30 of Set 14 | bulgan
# Processing Record 31 of Set 14 | mogok
# Processing Record 32 of Set 14 | bakchar
# Processing Record 33 of Set 14 | verkhnyaya inta
# Processing Record 34 of Set 14 | mbandaka
# Processing Record 35 of Set 14 | dunda
# Processing Record 36 of Set 14 | port talbot
# Processing Record 37 of Set 14 | chitrakonda
# Processing Record 38 of Set 14 | chake chake
# Processing Record 39 of Set 14 | chanute
# Processing Record 40 of Set 14 | sumen
# City not found. Skipping...
# Processing Record 41 of Set 14 | skjervoy
# Processing Record 42 of Set 14 | anchorage
# Processing Record 43 of Set 14 | humberto de campos
# Processing Record 44 of Set 14 | sao joao da barra
# Processing Record 45 of Set 14 | nador
# Processing Record 46 of Set 14 | caceres
# Processing Record 47 of Set 14 | san lorenzo
# Processing Record 48 of Set 14 | lagoa da prata
# Processing Record 49 of Set 14 | corinth
# Processing Record 50 of Set 14 | gumushane
# City not found. Skipping...
# Processing Record 1 of Set 15 | kaputa
# Processing Record 2 of Set 15 | maningrida
# Processing Record 3 of Set 15 | havoysund
# Processing Record 4 of Set 15 | palatka
# Processing Record 5 of Set 15 | toamasina
# Processing Record 6 of Set 15 | hohhot
# Processing Record 7 of Set 15 | kawalu
# Processing Record 8 of Set 15 | kahului
# Processing Record 9 of Set 15 | sault sainte marie
# Processing Record 10 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 15 | kota kinabalu
# Processing Record 12 of Set 15 | kalmunai
# Processing Record 13 of Set 15 | lenine
# Processing Record 14 of Set 15 | winnemucca
# Processing Record 15 of Set 15 | fairview
# Processing Record 16 of Set 15 | tamandare
# Processing Record 17 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 15 | kabanjahe
# Processing Record 19 of Set 15 | kolosovka
# Processing Record 20 of Set 15 | sarangani
# Processing Record 21 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 15 | ilhabela
# Processing Record 23 of Set 15 | kungurtug
# Processing Record 24 of Set 15 | saint-leu
# Processing Record 25 of Set 15 | yerbogachen
# Processing Record 26 of Set 15 | urucara
# Processing Record 27 of Set 15 | korla
# Processing Record 28 of Set 15 | quatre cocos
# Processing Record 29 of Set 15 | qeshm
# Processing Record 30 of Set 15 | puerto suarez
# Processing Record 31 of Set 15 | ketchikan
# Processing Record 32 of Set 15 | sokoni
# Processing Record 33 of Set 15 | brownsville
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | preobrazheniye
# Processing Record 36 of Set 15 | koltubanovskiy
# Processing Record 37 of Set 15 | polunochnoye
# Processing Record 38 of Set 15 | visnes
# Processing Record 39 of Set 15 | fuling
# Processing Record 40 of Set 15 | ilo
# Processing Record 41 of Set 15 | ornskoldsvik
# Processing Record 42 of Set 15 | port augusta
# Processing Record 43 of Set 15 | invermere
# Processing Record 44 of Set 15 | meulaboh
# Processing Record 45 of Set 15 | rawatsar
# Processing Record 46 of Set 15 | neuquen
# Processing Record 47 of Set 15 | moree
# Processing Record 48 of Set 15 | roebourne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0         Almeirim      BR  2022-08-08 16:10:26  -1.5233  -52.5817     90.91
# 1  Arraial Do Cabo      BR  2022-08-08 16:15:09 -22.9661  -42.0278     75.16
# 2            Bluff      NZ  2022-08-08 16:15:09 -46.6000  168.3333     34.81
# 3          Ushuaia      AR  2022-08-08 16:11:37 -54.8000  -68.3000     40.66
# 4           Carman      CA  2022-08-08 16:15:10  49.4992  -98.0016     75.54
# 5            Kapaa      US  2022-08-08 16:12:19  22.0752 -159.3190     75.52
# 6     Port Lincoln      AU  2022-08-08 16:15:10 -34.7333  135.8667     53.29
# 7          Te Anau      NZ  2022-08-08 16:15:11 -45.4167  167.7167     20.52
# 8      Provideniya      RU  2022-08-08 16:15:11  64.3833 -173.3000     36.21
# 9         Langfang      CN  2022-08-08 16:11:33  39.5097  116.6947     72.19
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        47           7        6.60           clear sky
# 1        78          75       10.36          light rain
# 2        67           2       18.01           clear sky
# 3        52          20        3.44          few clouds
# 4        60          30        6.91    scattered clouds
# 5        84          40       13.80    scattered clouds
# 6        76           0       11.18           clear sky
# 7        97          81        1.72       broken clouds
# 8        77          92       10.83     overcast clouds
# 9        70         100        5.12     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
